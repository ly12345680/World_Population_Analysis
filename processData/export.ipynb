# %%
# processing "world_population.csv"
import pandas as pd

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV
data = pd.read_csv('./asset/data/world_population.csv')

data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 # Đọc dữ liệu từ file CSV
# ----> 4 data = pd.read_csv('./asset/data/world_population.csv')
#       6 data.head()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './asset/data/world_population.csv'

# %%
data = data.drop(['CCA3', 'Capital', 'World Population Percentage'], axis=1)

# %%
data.to_csv('world_population.csv', index=False)

# %%
# processing "Global_annual_mean_temp.csv"

# %%
data2 = pd.read_csv('./asset/data/Global_annual_population.csv')

data2.head()
data2 = data2.drop(['Unnamed: 2'], axis=1)
data2.head()
data2.to_csv('Global_annual_population.csv', index=False)

# %%
import pandas as pd

# Load the data
df = pd.read_csv('../asset/data/world_population.csv')

# Calculate the sum of population for each year
df_sum = df.iloc[:, 4:10].sum(axis=0)


# # Save the sum DataFrame to a new CSV file
df_sum.to_csv('d2.csv', index_label=['Year', 'Total Population'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/nguyenhaiharry/Library/CloudStorage/OneDrive-VietNamNationalUniversity-HCMINTERNATIONALUNIVERSITY/Desktop/Sem1_2023-2024/Project_DSDV/World_Population_Analysis/processData/export.ipynb Cell 8 line 4
#       <a href='vscode-notebook-cell:/Users/nguyenhaiharry/Library/CloudStorage/OneDrive-VietNamNationalUniversity-HCMINTERNATIONALUNIVERSITY/Desktop/Sem1_2023-2024/Project_DSDV/World_Population_Analysis/processData/export.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/nguyenhaiharry/Library/CloudStorage/OneDrive-VietNamNationalUniversity-HCMINTERNATIONALUNIVERSITY/Desktop/Sem1_2023-2024/Project_DSDV/World_Population_Analysis/processData/export.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> # Load the data
# ----> <a href='vscode-notebook-cell:/Users/nguyenhaiharry/Library/CloudStorage/OneDrive-VietNamNationalUniversity-HCMINTERNATIONALUNIVERSITY/Desktop/Sem1_2023-2024/Project_DSDV/World_Population_Analysis/processData/export.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> df = pd.read_csv('../asset/data/world_populatio2.csv')
#       <a href='vscode-notebook-cell:/Users/nguyenhaiharry/Library/CloudStorage/OneDrive-VietNamNationalUniversity-HCMINTERNATIONALUNIVERSITY/Desktop/Sem1_2023-2024/Project_DSDV/World_Population_Analysis/processData/export.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> # Calculate the sum of population for each year
#       <a href='vscode-notebook-cell:/Users/nguyenhaiharry/Library/CloudStorage/OneDrive-VietNamNationalUniversity-HCMINTERNATIONALUNIVERSITY/Desktop/Sem1_2023-2024/Project_DSDV/World_Population_Analysis/processData/export.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> df_sum = df.iloc[:, 4:10].sum(axis=0)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../asset/data/world_populatio2.csv'

# %%
df = pd.read_csv('d2.csv')
df.head()
dfDrop = df.drop(['0'], axis=1)
dfDrop.head()
dfDrop.to_csv('d2.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('d2.csv')
#       2 df.head()
#       3 dfDrop = df.drop(['0'], axis=1)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd2.csv'

# %%
# processing "world_population2.csv"
df = pd.read_csv('../asset/data/world_population2.csv')

df['Year'] = df['Year'].str.replace(' Population', '')
df
df.to_csv('world_population2.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       1 # processing "world_population2.csv"
#       2 df = pd.read_csv('../asset/data/world_population2.csv')
# ----> 4 df['Year'] = df['Year'].str.replace(' Population', '')
#       5 df
#       6 df.to_csv('world_population2.csv', index=False)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:6202, in NDFrame.__getattr__(self, name)
#    6195 if (
#    6196     name not in self._internal_names_set
#    6197     and name not in self._metadata
#    6198     and name not in self._accessors
#    6199     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6200 ):
#    6201     return self[name]
# -> 6202 return object.__getattribute__(self, name)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/strings/accessor.py:190, in StringMethods.__init__(self, data)
#     187 def __init__(self, data) -> None:
#     188     from pandas.core.arrays.string_ import StringDtype
# --> 190     self._inferred_dtype = self._validate(data)
#     191     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     192     self._is_string = isinstance(data.dtype, StringDtype)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/strings/accessor.py:244, in StringMethods._validate(data)
#     241 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     243 if inferred_dtype not in allowed_types:
# --> 244     raise AttributeError("Can only use .str accessor with string values!")
#     245 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
import pandas as pd

# Load the original dataset
df = pd.read_csv('../asset/data/world_population.csv')

# Reshape the DataFrame
df_melted = df.melt(id_vars=["Rank","Country/Territory","Continent","Area (km²)", "Density (per km²)", "Growth Rate"], var_name='Year', value_name='Population')
df_melted['Year'] = df_melted['Year'].str.replace(' Population', '')
df_melted.head(30)
# Export the new dataset
# df2 = pd.read_csv('../asset/data/world_population.csv')
# df2.head()
# df_melted.to_csv('new_dataset.csv', index=False)
# Out:
#     Rank       Country/Territory      Continent  Area (km²)  \
# 0     36             Afghanistan           Asia      652230
# 1    138                 Albania         Europe       28748
# 2     34                 Algeria         Africa     2381741
# 3    213          American Samoa        Oceania         199
# 4    203                 Andorra         Europe         468
# 5     42                  Angola         Africa     1246700
# 6    224                Anguilla  North America          91
# 7    201     Antigua and Barbuda  North America         442
# 8     33               Argentina  South America     2780400
# 9    140                 Armenia           Asia       29743
# 10   198                   Aruba  North America         180
# 11    55               Australia        Oceania     7692024
# 12    99                 Austria         Europe       83871
# 13    91              Azerbaijan           Asia       86600
# 14   176                 Bahamas  North America       13943
# 15   154                 Bahrain           Asia         765
# 16     8              Bangladesh           Asia      147570
# 17   186                Barbados  North America         430
# 18    96                 Belarus         Europe      207600
# 19    81                 Belgium         Europe       30528
# 20   177                  Belize  North America       22966
# 21    77                   Benin         Africa      112622
# 22   206                 Bermuda  North America          54
# 23   165                  Bhutan           Asia       38394
# 24    80                 Bolivia  South America     1098581
# 25   137  Bosnia and Herzegovina         Europe       51209
# 26   144                Botswana         Africa      582000
# 27     7                  Brazil  South America     8515767
# 28   221  British Virgin Islands  North America         151
# 29   175                  Brunei           Asia        5765
#
#     Density (per km²)  Growth Rate  Year  Population
# 0             63.0587       1.0257  2022    41128771
# 1             98.8702       0.9957  2022     2842321
# 2             18.8531       1.0164  2022    44903225
# 3            222.4774       0.9831  2022       44273
# 4            170.5641       1.0100  2022       79824
# 5             28.5466       1.0315  2022    35588987
# 6            174.2527       1.0066  2022       15857
# 7            212.1335       1.0058  2022       93763
# 8             16.3683       1.0052  2022    45510318
# 9             93.4831       0.9962  2022     2780469
# 10           591.3611       0.9991  2022      106445
# 11             3.4032       1.0099  2022    26177413
# 12           106.5877       1.0020  2022     8939617
# 13           119.6082       1.0044  2022    10358074
# 14            29.4043       1.0051  2022      409984
# 15          1924.4876       1.0061  2022     1472233
# 16          1160.0350       1.0108  2022   171186372
# 17           654.9651       1.0015  2022      281635
# 18            45.9295       0.9955  2022     9534954
# 19           381.8111       1.0038  2022    11655930
# 20            17.6466       1.0131  2022      405272
# 21           118.5635       1.0274  2022    13352864
# 22          1188.5926       1.0000  2022       64184
# 23            20.3796       1.0064  2022      782455
# 24            11.1272       1.0120  2022    12224110
# 25            63.1437       0.9886  2022     3233526
# 26             4.5194       1.0162  2022     2630296
# 27            25.2841       1.0046  2022   215313498
# 28           207.3179       1.0059  2022       31305
# 29            77.8841       1.0081  2022      449002
